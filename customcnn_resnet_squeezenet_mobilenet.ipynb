# %%
#pip install torch torchvision torchaudio

# %%
#pip -q install torchxrayvision

# %%
#%env CUDA_VISIBLE_DEVICES=2

import torch, torchvision
from torchvision import datasets, models, transforms
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms
import time
from torchsummary import summary
import torchxrayvision as xrv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import shutil
from sklearn.model_selection import train_test_split
from PIL import Image

# %% [markdown]
# ##Baixando dados

# %%
# !git clone https://github.com/ieee8023/covid-chestxray-dataset
# Out:
# fatal: destination path 'covid-chestxray-dataset' already exists and is not an empty directory.

# %%
data = xrv.datasets.COVID19_Dataset(imgpath="covid-chestxray-dataset/images/",csvpath="covid-chestxray-dataset/metadata.csv")

# %%
data
# Out:
# {'Aspergillosis': {np.float32(0.0): 534, np.float32(1.0): 1},
#  'Aspiration': {np.float32(0.0): 534, np.float32(1.0): 1},
#  'Bacterial': {np.float32(0.0): 487, np.float32(1.0): 48},
#  'COVID-19': {np.float32(0.0): 193, np.float32(1.0): 342},
#  'Chlamydophila': {np.float32(0.0): 534, np.float32(1.0): 1},
#  'Fungal': {np.float32(0.0): 512, np.float32(1.0): 23},
#  'H1N1': {np.float32(0.0): 534, np.float32(1.0): 1},
#  'Herpes ': {np.float32(0.0): 532, np.float32(1.0): 3},
#  'Influenza': {np.float32(0.0): 531, np.float32(1.0): 4},
#  'Klebsiella': {np.float32(0.0): 526, np.float32(1.0): 9},
#  'Legionella': {np.float32(0.0): 526, np.float32(1.0): 9},
#  'Lipoid': {np.float32(0.0): 527, np.float32(1.0): 8},
#  'MERS-CoV': {np.float32(0.0): 527, np.float32(1.0): 8},
#  'MRSA': {np.float32(0.0): 534, np.float32(1.0): 1},
#  'Mycoplasma': {np.float32(0.0): 530, np.float32(1.0): 5},
#  'No Finding': {np.float32(0.0): 520, np.float32(1.0): 15},
#  'Nocardia': {np.float32(0.0): 531, np.float32(1.0): 4},
#  'Pneumocystis': {np.float32(0.0): 513, np.float32(1.0): 22},
#  'Pneumonia': {np.float32(0.0): 26, np.float32(1.0): 509},
#  'SARS': {np.float32(0.0): 519, np.float32(1.0): 16},
#  'Staphylococcus': {np.float32(0.0): 534, np.float32(1.0): 1},
#  'Streptococcus': {np.float32(0.0): 518, np.float32(1.0): 17},
#  'Tuberculosis': {np.float32(0.0): 524, np.float32(1.0): 11},
#  'Varicella': {np.float32(0.0): 530, np.float32(1.0): 5},
#  'Viral': {np.float32(0.0): 157, np.float32(1.0): 378}}
# COVID19_Dataset num_samples=535 views=['PA', 'AP'] data_aug=None

# %%
df = data.csv

# %%
labels = []
imgs = []

for i in range(len(data)):
    pd.Series(dict(zip(data.pathologies,data[i]["lab"])))
    labels.append(pd.Series(dict(zip(data.pathologies,data[i]["lab"]))))
    imgs.append(data[i]["img"])

labels = pd.DataFrame(labels)
imgs = [i[0] for i in imgs]

# %%
# prompt: encontrar casos onde todos os registros são 0

zeros = []
for index, row in labels.iterrows():
    if row.sum() == 0:
        zeros.append(index)
print(f"Indices where all records are zero: {zeros}")
# Out:
# Indices where all records are zero: []

# %%
labels = labels['COVID-19']

# %%
labels.value_counts()
# Out:
# COVID-19
# 1.0    342
# 0.0    193
# Name: count, dtype: int64

# %%
plt.imshow(imgs[1], cmap='gray')
plt.axis('off')
plt.show()

# %%
label_map = {
    0: 'Non-COVID',
    1: 'COVID-19'
}

# %%
base_dir = 'chestxray'
for split in ['train', 'val', 'test']:
    for label in label_map.values():
        os.makedirs(os.path.join(base_dir, split, label), exist_ok=True)

# %%
X_temp, X_test, y_temp, y_test = train_test_split(imgs, labels, test_size=0.15, stratify=labels, random_state=12)
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.12, stratify=y_temp, random_state=33)

# %%
def save_images(img_list, label_list, split):
    for i, (img, label) in enumerate(zip(img_list, label_list)):
        folder = os.path.join(base_dir, split, label_map[label])

        # Se for numpy array float, converte para uint8 [0-255]
        if isinstance(img, np.ndarray):
            if img.dtype != np.uint8:
                img = (img * 255).astype(np.uint8)
            img = Image.fromarray(img)

        # Se for imagem PIL, mas em modo float, converte para RGB (ou L, dependendo do caso)
        elif img.mode == 'F':
            img = img.convert('RGB')  # ou 'L' para grayscale

        img.save(os.path.join(folder, f"{split}_{i}.png"))

# %%
save_images(X_train, y_train, 'train')
save_images(X_val, y_val, 'val')
save_images(X_test, y_test, 'test')

# %% [markdown]
# ##Funções gerais

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# Applying Transforms to the Data
# pre-trained models expect data with the same pre processing as data it was originally trained on
# thus those transformations are necessary
# + a bit of data augmentation
# podem resizes de tamanhos diferentes?
image_transforms = {
    'train': transforms.Compose([
        transforms.Grayscale(num_output_channels=3), #xrays are b&w but densenet expects rgb
        transforms.Resize(256),
        transforms.ColorJitter(brightness=0.2, contrast=0.2),
        #transforms.RandomResizedCrop(size=332, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees=5),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(), #image (format PIL) -> tensor (format pytorch)
        #normalizar por 255 - ToTensor já faz isso automatico
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    #val and test's transformations are deterministic (no noise, no diversity generated)
    'val': transforms.Compose([
        transforms.Grayscale(num_output_channels=3),
        transforms.Resize(size=224),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Grayscale(num_output_channels=3),
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])
}

# %%
image_transforms_for_custom_networks = {
    'train': transforms.Compose([
        transforms.Grayscale(num_output_channels=1),
        transforms.Resize(256),
        transforms.RandomRotation(degrees=5),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.488], [0.488])
    ]),
    'val': transforms.Compose([
        transforms.Grayscale(num_output_channels=1),
        transforms.Resize(size=224),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.488], [0.488])
    ]),
    'test': transforms.Compose([
        transforms.Grayscale(num_output_channels=1),
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.488], [0.488])
    ])
}

# %%
# Load the Data

os.makedirs('chestxray/train/Non-COVID', exist_ok=True)
os.makedirs('chestxray/train/COVID-19', exist_ok=True)

os.makedirs('chestxray/val/Non-COVID', exist_ok=True)
os.makedirs('chestxray/val/COVID-19', exist_ok=True)

os.makedirs('chestxray/test/Non-COVID', exist_ok=True)
os.makedirs('chestxray/test/COVID-19', exist_ok=True)

# Set train and valid directory paths
dataset = 'chestxray'
train_directory = os.path.join(dataset, 'train') #chestxray/train
val_directory = os.path.join(dataset, 'val') #chestxray/val
test_directory = os.path.join(dataset, 'test') #chestxray/test

# mini batch size
bs = 16

#needed: #chestxray/train/covid
         #chestxray/train/noncovid
         #chestxray/val/covid
         #chestxray/val/noncovid
         #chestxray/test/covid
         #chestxray/test/noncovid

# Number of classes
num_classes = len(os.listdir(train_directory)) #num classes = num folds in each set fold

# Load Data from folders and apply transformations we set
data = {
    'train': datasets.ImageFolder(root=train_directory, transform=image_transforms['train']),
    'val': datasets.ImageFolder(root=val_directory, transform=image_transforms['val']),
    'test': datasets.ImageFolder(root=test_directory, transform=image_transforms['test'])
}

# Get a mapping of the indices to the class names, in order to see the output classes of the test images.
# ImageFolder creates mapping {class name: number}
# here the opposite is done: {number : class name} so we know the class outputted by its associated index
idx_to_class = {v: k for k, v in data['train'].class_to_idx.items()}
print(idx_to_class)

# Size of Data, to be used for calculating Average Loss and Accuracy
train_data_size = len(data['train'])
val_data_size = len(data['val'])
test_data_size = len(data['test'])
print(train_data_size, val_data_size, test_data_size)

# Create iterators for the Data loaded using DataLoader module
# batch generators
train_data_loader = DataLoader(data['train'], batch_size=bs, shuffle=True) #not learning sequences here
val_data_loader = DataLoader(data['val'], batch_size=bs, shuffle=False)
test_data_loader = DataLoader(data['test'], batch_size=bs, shuffle=False)
# Out:
# {0: 'COVID-19', 1: 'Non-COVID'}
# 399 55 81

# %%
#essas redes foram treinadas em imagens preto e branco, logo, 1 canal. até agora, estava usando transformacoes que expandiam nossas imagens p&b pra rgb
#(como descongelei a camada convolucional - no fine tuning - , então o número de canais precisa coincidir com o que foi treinado)
#ent preciso refazer essa parte do processamento, chamando a funcao que não expande o número de canais
data = {
    'train': datasets.ImageFolder(root=train_directory, transform=image_transforms_for_custom_networks['train']),
    'val': datasets.ImageFolder(root=val_directory, transform=image_transforms_for_custom_networks['val']),
    'test': datasets.ImageFolder(root=test_directory, transform=image_transforms_for_custom_networks['test'])
}

idx_to_class = {v: k for k, v in data['train'].class_to_idx.items()}
print(idx_to_class)

train_data_size = len(data['train'])
val_data_size = len(data['val'])
test_data_size = len(data['test'])

train_data_loader_for_custom_networks = DataLoader(data['train'], batch_size=bs, shuffle=True) #not learning sequences here
val_data_loader_for_custom_networks = DataLoader(data['val'], batch_size=bs, shuffle=False)
test_data_loader_for_custom_networks = DataLoader(data['test'], batch_size=bs, shuffle=False)
# Out:
# {0: 'COVID-19', 1: 'Non-COVID'}

# %%
def train_and_validate(model, loss_criterion, optimizer, epochs, dataset="chestxraytry",
                       train_data_loader=train_data_loader, val_data_loader=val_data_loader, train_data_size=train_data_size,
                       val_data_size=val_data_size, device=device):

    start = time.time()
    history = []
    best_loss = 100000.0
    best_epoch = None

    #first: looping through training
    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))

        # Set to training mode -> activates dropout, batch norm, early stopping
        model.train()

        # Loss and Accuracy and Recall within the epoch
        train_loss = 0.0
        train_acc = 0.0
        valid_loss = 0.0
        valid_acc = 0.0
        valid_true_positives = 0.0
        valid_false_negatives = 0.0

        #for each batch
        for i, (inputs, labels) in enumerate(train_data_loader):

            inputs = inputs.to(device)
            labels = labels.to(device)

            # Clean existing gradients
            optimizer.zero_grad()

            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)

            # Compute loss
            loss = loss_criterion(outputs, labels)

            # Backpropagate the gradients
            loss.backward()

            # Update the parameters
            optimizer.step()

            # Compute the total loss for the batch and add it to train_loss
            # loss.item() returns average loss for the batch,
            # so we multiply by batch size to get an estimation of the sum for the batch
            #(so we can obtain the average loss over the whole dataset later)
            train_loss += loss.item() * inputs.size(0)

            # Compute the accuracy
            # TODO sugiro usar metrics do sklearn 
            _, predictions = torch.max(outputs.data, 1) #returns index of most probable class for each instance - the actual predictions for each batch instance
            correct_counts = predictions.eq(labels.data.view_as(predictions)) #compares predictions with labels resulting in a bool tensor (1 if right, 0 if not)
            acc = torch.mean(correct_counts.type(torch.FloatTensor)) #convert correct_counts to float and then compute the mean (fraction of sucesses in the batch)
            train_acc += acc.item() * inputs.size(0) #multiply this mean by batch size to evaluate the total accuracy later
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))


        # Validation - no gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode -> dropout off, batch norm fixed
            model.eval()

            # for each validation batch -> similar logic
            for j, (inputs, labels) in enumerate(val_data_loader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                _, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))
                acc = torch.mean(correct_counts.type(torch.FloatTensor))
                valid_acc += acc.item() * inputs.size(0)
                valid_true_positives += ((predictions == 1) & (labels == 1)).sum().item() #total of true positives
                valid_false_negatives += ((predictions == 0) & (labels == 1)).sum().item() #total of false negatives
                #print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))

        # is this the best model based on tinniest validation loss?
        if valid_loss < best_loss:
            best_loss = valid_loss
            best_epoch = epoch

        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size
        avg_train_acc = train_acc/train_data_size
        avg_valid_loss = valid_loss/val_data_size
        avg_valid_acc = valid_acc/val_data_size
        valid_recall = valid_true_positives / (valid_true_positives + valid_false_negatives + 1e-7) #avoids 0 division
        #scheduler.step(avg_valid_loss)

        history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc, valid_recall])
        epoch_end = time.time()
        print("Epoch : {:03d}, Training: Loss - {:.4f}, Accuracy - {:.4f}%, \n\t\tValidation : Loss - {:.4f}, Accuracy - {:.4f}%, Recall - {:.4f}, Time: {:.4f}s".format(epoch, avg_train_loss, avg_train_acc*100, avg_valid_loss, avg_valid_acc*100, valid_recall, epoch_end-epoch_start))

        # Save if the model has best accuracy till now
        torch.save(model, dataset+'_model_'+str(epoch)+'.pt')

    return model, history, best_epoch

# %%
def train_and_validate_for_custom_networks(model, loss_criterion, optimizer, epochs, dataset="chestxraytry",
                       train_data_loader=train_data_loader_for_custom_networks, val_data_loader=val_data_loader_for_custom_networks, train_data_size=train_data_size,
                       val_data_size=val_data_size, device=device):
    
    start = time.time()
    history = []
    best_loss = 100000.0
    best_epoch = None

    #first: looping through training
    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))

        # Set to training mode -> activates dropout, batch norm, early stopping
        model.train()

        # Loss and Accuracy and Recall within the epoch
        train_loss = 0.0
        train_acc = 0.0
        valid_loss = 0.0
        valid_acc = 0.0
        valid_true_positives = 0.0
        valid_false_negatives = 0.0

        #for each batch
        for i, (inputs, labels) in enumerate(train_data_loader):

            inputs = inputs.to(device)
            labels = labels.to(device)

            # Clean existing gradients
            optimizer.zero_grad()

            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)

            # Compute loss
            loss = loss_criterion(outputs, labels)

            # Backpropagate the gradients
            loss.backward()

            # Update the parameters
            optimizer.step()

            # Compute the total loss for the batch and add it to train_loss
            # loss.item() returns average loss for the batch,
            # so we multiply by batch size to get an estimation of the sum for the batch
            #(so we can obtain the average loss over the whole dataset later)
            train_loss += loss.item() * inputs.size(0)

            # Compute the accuracy
            _, predictions = torch.max(outputs.data, 1) #returns index of most probable class for each instance - the actual predictions for each batch instance
            correct_counts = predictions.eq(labels.data.view_as(predictions)) #compares predictions with labels resulting in a bool tensor (1 if right, 0 if not)
            acc = torch.mean(correct_counts.type(torch.FloatTensor)) #convert correct_counts to float and then compute the mean (fraction of sucesses in the batch)
            train_acc += acc.item() * inputs.size(0) #multiply this mean by batch size to evaluate the total accuracy later
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))


        # Validation - no gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode -> dropout off, batch norm fixed
            model.eval()

            # for each validation batch -> similar logic
            for j, (inputs, labels) in enumerate(val_data_loader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                _, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))
                acc = torch.mean(correct_counts.type(torch.FloatTensor))
                valid_acc += acc.item() * inputs.size(0)
                valid_true_positives += ((predictions == 1) & (labels == 1)).sum().item() #total of true positives
                valid_false_negatives += ((predictions == 0) & (labels == 1)).sum().item() #total of false negatives
                #print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))

        # is this the best model based on tinniest validation loss?
        if valid_loss < best_loss:
            best_loss = valid_loss
            best_epoch = epoch

        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size
        avg_train_acc = train_acc/train_data_size
        avg_valid_loss = valid_loss/val_data_size
        avg_valid_acc = valid_acc/val_data_size
        valid_recall = valid_true_positives / (valid_true_positives + valid_false_negatives + 1e-7) #avoids 0 division
        #scheduler.step(avg_valid_loss)

        history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc, valid_recall])
        epoch_end = time.time()
        print("Epoch : {:03d}, Training: Loss - {:.4f}, Accuracy - {:.4f}%, \n\t\tValidation : Loss - {:.4f}, Accuracy - {:.4f}%, Recall - {:.4f}, Time: {:.4f}s".format(epoch, avg_train_loss, avg_train_acc*100, avg_valid_loss, avg_valid_acc*100, valid_recall, epoch_end-epoch_start))

        # Save if the model has best accuracy till now
        torch.save(model, dataset+'_model_'+str(epoch)+'.pt')

    return model, history, best_epoch

# %%
def computeTestSetPerformance(model, loss_criterion, device):
    # Function to compute the accuracy on the test set

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    test_acc = 0.0
    test_loss = 0.0
    test_true_positives = 0.0
    test_false_negatives = 0.0

    # Validation - No gradient tracking needed
    with torch.no_grad():

        # Set to evaluation mode
        model.eval()

        # for each batch in test
        for j, (inputs, labels) in enumerate(test_data_loader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)

            # Compute loss
            loss = loss_criterion(outputs, labels)

            # Compute the total loss for the batch and add it to valid_loss
            test_loss += loss.item() * inputs.size(0)
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            test_acc += acc.item() * inputs.size(0)
            test_true_positives += ((predictions == 1) & (labels == 1)).sum().item()
            test_false_negatives += ((predictions == 0) & (labels == 1)).sum().item()

            print("Test Batch number: {:03d}, Test: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))

    # Find average test loss and test accuracy and recall
    avg_test_loss = test_loss/test_data_size
    avg_test_acc = test_acc/test_data_size
    test_recall = test_true_positives / (test_true_positives + test_false_negatives + 1e-7)

    print("Test accuracy : " + str(avg_test_acc))

# %%
def predict(model, test_image_name):
    #Function to predict the class of a single test image

    transform = image_transforms['test'] #loads pre processing needed into test images in 'transform' object
    test_image = Image.open(test_image_name)
    plt.imshow(test_image)
    test_image_tensor = transform(test_image) #applies the processing

    if torch.cuda.is_available():
      #view regorganized tensor so its format is (batch size X number of channels X height X depth)
        #test_image_tensor = test_image_tensor.view(1, 3, 224, 224).cuda()
        #unsqueeze(dim) adds dimension of size 1 at position dim
        test_image_tensor = test_image_tensor.unsqueeze(0).cuda()
    else:
        #test_image_tensor = test_image_tensor.view(1, 3, 224, 224)
        test_image_tensor = test_image_tensor.unsqueeze(0)

    with torch.no_grad():
        model.eval()
        # Model outputs log probabilities
        out = model(test_image_tensor) #model outputs (probabilities for each class)
        #ps = torch.exp(out) #for LogSoftMax activation

        topk, topclass = out.topk(1, dim=1) #most likely class
        cls = idx_to_class[topclass.cpu().numpy()[0][0]]
        score = topk.cpu().numpy()[0][0]
        print("Prediction:", cls, ", with probability:", score) #shows most likely class

# %% [markdown]
# ##Custom CNNs

# %% [markdown]
# O artigo abaixo serviu como nosso principal guia e referência no trabalho. Ele apresenta uma revisão sistemática de mais de 80 trabalhos relacionados à classificação de doenças respiratórias a partir de imagens de raios x.

# %% [markdown]
# [main survey](https://pdf.sciencedirectassets.com/271150/1-s2.0-S0010482522X00036/1-s2.0-S0010482522001421/main.pdf?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEHkaCXVzLWVhc3QtMSJHMEUCICbSt7ToUl2VCfNIrtnY%2BXOaGCkEnChW%2BQGxQBiMSU%2FyAiEAjxyHHh7C6CdBFHyQkmvvO9pIMG5nXcrSqSc7nLs33JkqswUIYhAFGgwwNTkwMDM1NDY4NjUiDHsiNblRBwF1FkxAGCqQBY9E8Be%2BH9ecZ7gKoRLfG%2BXMSoYapam6h33qIThoBkiMiHokZSOQ1dSp6NFalbSb0Htg6rMng3Schfi37dYXQm0AOTKhBQ%2F4gzYSQrdW%2Bwmqg1jamU%2FHy5DhavmcSoUXAMJKYQdl0NZYDJr70hnC6rICDdPLc2OFYltQZx69kICwVqThd%2BQVgBzTYkbqrzBUI7KOCmiJtZzcomUGdK6TRMXFcIyxo5W%2BwJ6iplZraXC2azWhOfn3hQC6HlMpVTHD7nEPq%2ByXdxKQQ0DAhm4wCVR%2BjZZWzFby3lEry2b7imxIsqQvpD10ITBO4nHl9zXKgK2%2B76baxi%2BHwQsOA89pYCwkC%2FqCDgLTHJOqoZUo9XkThSJyYSixRZlcODwqO8l2I%2BqdqkEeJ8z%2FrqZ7BVeZAg6b9TH3dLGe8xm2ZC%2FbCGzMr3FHL4RSZXruaKytEioHK9Ti%2FJNkccKlHCBLCN2MplthyhKg2OrF3o%2FQYvz0n%2BdmOEyDALW6MACQjwxtreX%2BtYtM1J97%2B04l2BAgY7E4LwTVuCq7384VsIghyyBgDzdQf6SRGhjY690uvS97QIsCotaXwsz8zeQTxD6Q%2Fl0soahsQeobxwBPdbQHdWlHq%2FWXqCPUo%2BUTzbqjId%2BkZnnOm2T4Mn9eWuRq6j2215QcmUNwjKGBcAyneVjZL4fi7fP5l1DQf2Qay74A7PHrQtYnGkVUfybDufx7Cw%2BwdI4zxKUnV1WeAw36ooL0vLYmvC6%2B0bz77b1M8zKdYIM3YiSSVyeIKxoGtjDVUfs3Yxomp1C0eJ4O8GR3TEKG3hOWZddGyfkvrH9YoerdAPnYF8zVN8kmZxiVoUFojaWk%2Fo8m2ngv4wo35UWGH7GZYiow3%2FG2MLmUwcIGOrEB3PQhhIFT4%2Fu3nLN6Qkq%2BV58JFqUp1ugAB%2B%2FbX685jK%2BDiKQ7sphhzek2BWcryMe98luzomRbSSDIv7tyx%2BT3bu3jHb5jP0sXrYftJNNZDoqzWzIYJUtCqKQHoffTdaqo14%2F6DE6b2WuxVJZoccwWmdtp49IY2bwKXMifq01aCVsgf3mhrA32%2Bb%2BLgat0jRY1nd7nnlYqwEl73g1SH6f1YOHFvwuPgmcMhTSHfft%2BPZwk&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20250616T174659Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAQ3PHCVTY7XQJ6UOL%2F20250616%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=e60186f63a574c4f727e30fc774bcb688a1e26dab8c43d31e177e2878993ed15&hash=8ffe4ac4c95cd2bf98560d87a224d1cfdbc506d15c5968c6769731b1a2343312&host=68042c943591013ac2b2430a89b270f6af2c76d8dfd086a07176afe7c76c2c61&pii=S0010482522001421&tid=spdf-b3ee99b0-90df-4e3a-b828-fc12bbc5bb9a&sid=70e8c7515cae084e9b3b3ff88eee33cbbcc2gxrqa&type=client&tsoh=d3d3LnNjaWVuY2VkaXJlY3QuY29t&rh=d3d3LnNjaWVuY2VkaXJlY3QuY29t&ua=18145b5b5f07525650&rr=950c21379f87b3a6&cc=br)

# %% [markdown]
# ###CoroDet

# %% [markdown]
# O trabalho abaixo chamou nossa atenção. A rede parecia muito bem descrita, incluindo o processo de treinamento e busca de parâmetros. Tentamos explorar e codar ela também. No entanto, tivemos alguns desafios: o tamanho inicial da nossa imagem era diferente, e tivemos receio de alterar a resolução do nosso dataset (e, portanto, seu poder "preditivo") ao adaptar as imagens para o tamanho esperado. Em vez disso, preferimos adaptar a rede para o tamanho de input que tínhamos, tentando preservar a lógica e estrutura geral

# %% [markdown]
# [link text](https://pdf.sciencedirectassets.com/271591/1-s2.0-S0960077920X00129/1-s2.0-S0960077920308870/main.pdf?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEJj%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIHZYoDSdzZpqMG05No2vUK9X%2BuAL6TlV7wtbTVQOnn9WAiEAo1EvoKsKl6UpfxhimsP5YSZpszHGSvJ02Ny7uOpwBSMqvAUIgP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAFGgwwNTkwMDM1NDY4NjUiDPj%2FYMr%2FHmsA2CCpHCqQBRL6hJBzn5AxjPhy9wSVwkIDzmyIN5BwyP8jmETES3IMA%2BQQYzSvQmOShv2yZICY%2F7iv46NXqnsDo0t4BVq%2Frf91hgPvewWPhvqAl%2Fv02fndNd2wst%2BYwtnH%2FXRDgJu9WkRKUwev1e6A408%2FoykNdS8wd1wpLZ8ey6o3CxKZM7EZ%2FehDe2wgUWz8jHA0p8ZMxzUZdB5E5QyDCVxioRfkdhU62%2BJm9GlSW1xT11z0JoyMqaeeawixE2nVz%2FoT1fKZumdUxVajo%2BoTQ%2BjLggP3MVcQZfrPgtM8VjnDd1UZyrwPQDVta%2FgyWHrGYlsZngnxA9k7c1yt6m9MmuV5KgEPJHsDhd7sELiRAF9s%2FQebCbidwtemmo48NIp9eH6YOEuEMmcmfsxg4ruYNo2QbLzVwsCEw43WySdbHiuNO2MDciQ%2BknBnI40B8oV2oFbTQka12vVuosXrWQQyvNDKh6DlGzeTEoKKUVw1NV0DFrLHrYtvBZw3AsSvrh8DAOWIiMpO%2Fq4FeHElEB6V1%2BEzJBNCUM1tZnhy8v05bLL6cd%2B9Erwkdp7HvjbOJg2OScxjs253GBJTdNU1tt2Yn2bbrxcd2VMwEKUOyv4Hh0F38T0SbCxfI7BJk1o6eg0%2BYUpD51ar%2B57qhBidLpq6t3aVYRQznbu%2F0CAT%2FhqtTRzfGhT0hyDZaW4%2Bxbynznspq83S5Xn%2BaIxxhlWxDKc7lWOMBt3SY6b9ha5XqsnupqWdUdkmdEY7BWE8tfsxV8b%2B870B8zrSji8dv6B204HapO9ghUrSnG%2B1uwnEX30yDuv8kl5rqlKh7F1THkJ7LqJgedWjDciPXY8i%2FhVNxIBHTh5cvOUm6voZBm6UKmF7wL0E7zFDPVPsMIfxx8IGOrEB5HXP%2BD2kZOfnb1sZ6XDisXR93Pwm2RMu4YFqCtTJn4MEcl%2Bzi0G684KqXhcNOX2x3CWrDbV7hTeKZTRu8WRG0ZQG7ITo73OcFBkCFJtImjAaJV9GcVooPxteoz8bX0%2BZFckHBzy7ZZ3T8fgvfwIsla6fsaGKP8x797n9OUhzHVvP7UUOna5o5vvW40Q915IqQNbA34sf4V%2BIRF6VHYnsK7kOOOzR4qBRCzHRxCFQiLKi&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20250618T004640Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAQ3PHCVTYRJC6GMMA%2F20250618%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=64a5efd3856689c98a95d8b798f3eff7a1e14878408c1b93ce8b22dc9bd42147&hash=973716835f9ce6570bf1988c346745c234bca8fc0d92dc1f28f0492e56a20ce4&host=68042c943591013ac2b2430a89b270f6af2c76d8dfd086a07176afe7c76c2c61&pii=S0960077920308870&tid=spdf-00f92f72-74e4-457e-823d-a556d833884e&sid=addcb5187b4a1042b9390b70ed3c567b7c89gxrqa&type=client&tsoh=d3d3LnNjaWVuY2VkaXJlY3QuY29t&rh=d3d3LnNjaWVuY2VkaXJlY3QuY29t&ua=18145b5b5e52035256&rr=9516c55ff9016aa4&cc=br)

# %% [markdown]
# ![Screenshot 2025-06-16 at 15.12.20.png](data:image/png;base64,...)

# %%
images, labels = next(iter(train_data_loader))
print(images.shape)
# Out:
# torch.Size([16, 3, 224, 224])

# %%
class CoroDet(nn.Module):
    def __init__(self):
        super().__init__()

        self.features = nn.Sequential(
            # Input: (1, 224, 224) -> Output: (64, 37, 37)
            nn.Conv2d(1, 64, kernel_size=7, stride=6, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=2),  # (64, 18, 18)

            # Output: (128, 19, 19)
            nn.Conv2d(64, 128, kernel_size=4, stride=1, padding=2),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=2),  # (128, 9, 9)

            # Output: (64, 21, 21)
            nn.Conv2d(128, 64, kernel_size=5, stride=1, padding=4),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=2, padding=1),  # (64, 5, 5)

            # Output: (128, 21, 21)
            nn.Conv2d(64, 128, kernel_size=5, stride=1, padding=8),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=2, padding=1),  # (128, 3, 3)

            # Output: (256, 13, 13)
            nn.Conv2d(128, 256, kernel_size=4, stride=1, padding=6),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=2, padding=1),  # (256, 2, 2)

            # Output: (128, 15, 15)
            nn.Conv2d(256, 128, kernel_size=4, stride=1, padding=7),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=2, padding=1),  # (128, 1, 1)

            # Output: (256, 17, 17)
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=8),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=2, padding=1),  # (256, 1, 1)

            # Output: (128, 15, 15)
            nn.Conv2d(256, 128, kernel_size=4, stride=1, padding=6),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=2, padding=1),  # (128, 1, 1)

            # Output: (256, 15, 15)
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=7),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=2, padding=1)  # (256, 1, 1)
        )

        self.flatten = nn.Flatten()

        self.classifier = nn.Sequential(
            nn.Linear(256 * 13 * 13, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(),
            nn.Linear(512, 2)
        )

    def forward(self, x):
        for layer in self.features:
            x = layer(x)
        x = self.flatten(x)
        x = self.classifier(x)
        return x

# %%
model = CoroDet()
model = model.to(device)

# %%
optimizer = optim.Adam(model.parameters(), lr=0.00015)
loss_fn = nn.CrossEntropyLoss()

# %%
num_epochs = 50
trained_model, history, best_epoch = train_and_validate_for_custom_networks(model, loss_fn, optimizer, num_epochs)
torch.save(history, '_corodet_history.pt')
# Out:
# Epoch: 1/50
# Epoch : 000, Training: Loss - 0.7395, Accuracy - 55.8897%,
# 		Validation : Loss - 1.7718, Accuracy - 63.6364%, Recall - 0.0000, Time: 20.0459s
# Epoch: 2/50
# Epoch : 001, Training: Loss - 0.6428, Accuracy - 66.4160%,
# 		Validation : Loss - 7.6426, Accuracy - 63.6364%, Recall - 0.0000, Time: 23.4488s
# Epoch: 3/50
# Epoch : 002, Training: Loss - 0.6307, Accuracy - 68.4211%,
# 		Validation : Loss - 16.5549, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.7255s
# Epoch: 4/50
# Epoch : 003, Training: Loss - 0.6150, Accuracy - 67.1679%,
# 		Validation : Loss - 18.6215, Accuracy - 63.6364%, Recall - 0.0000, Time: 20.1306s
# Epoch: 5/50
# Epoch : 004, Training: Loss - 0.6061, Accuracy - 69.6742%,
# 		Validation : Loss - 181.6698, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.8027s
# Epoch: 6/50
# Epoch : 005, Training: Loss - 0.6094, Accuracy - 66.9173%,
# 		Validation : Loss - 1.4117, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.5421s
# Epoch: 7/50
# Epoch : 006, Training: Loss - 0.5897, Accuracy - 68.9223%,
# 		Validation : Loss - 109.3495, Accuracy - 36.3636%, Recall - 1.0000, Time: 20.0023s
# Epoch: 8/50
# Epoch : 007, Training: Loss - 0.5955, Accuracy - 68.9223%,
# 		Validation : Loss - 10.6313, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.5983s
# Epoch: 9/50
# Epoch : 008, Training: Loss - 0.5849, Accuracy - 69.9248%,
# 		Validation : Loss - 0.7289, Accuracy - 58.1818%, Recall - 0.8500, Time: 19.8660s
# Epoch: 10/50
# Epoch : 009, Training: Loss - 0.5744, Accuracy - 70.6767%,
# 		Validation : Loss - 94.5019, Accuracy - 36.3636%, Recall - 1.0000, Time: 19.5353s
# Epoch: 11/50
# Epoch : 010, Training: Loss - 0.5699, Accuracy - 72.9323%,
# 		Validation : Loss - 40.7477, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.6164s
# Epoch: 12/50
# Epoch : 011, Training: Loss - 0.5310, Accuracy - 73.9348%,
# 		Validation : Loss - 9.0906, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.5890s
# Epoch: 13/50
# Epoch : 012, Training: Loss - 0.5311, Accuracy - 73.1830%,
# 		Validation : Loss - 82.3783, Accuracy - 36.3636%, Recall - 1.0000, Time: 19.4597s
# Epoch: 14/50
# Epoch : 013, Training: Loss - 0.5390, Accuracy - 72.9323%,
# 		Validation : Loss - 63.4931, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.7054s
# Epoch: 15/50
# Epoch : 014, Training: Loss - 0.5070, Accuracy - 75.9398%,
# 		Validation : Loss - 86.1944, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.8061s
# Epoch: 16/50
# Epoch : 015, Training: Loss - 0.5196, Accuracy - 75.1880%,
# 		Validation : Loss - 106.2578, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.4112s
# Epoch: 17/50
# Epoch : 016, Training: Loss - 0.5000, Accuracy - 75.4386%,
# 		Validation : Loss - 3.3569, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.5569s
# Epoch: 18/50
# Epoch : 017, Training: Loss - 0.4931, Accuracy - 75.4386%,
# 		Validation : Loss - 58.5963, Accuracy - 36.3636%, Recall - 1.0000, Time: 19.6522s
# Epoch: 19/50
# Epoch : 018, Training: Loss - 0.5371, Accuracy - 73.9348%,
# 		Validation : Loss - 65.2105, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.4725s
# Epoch: 20/50
# Epoch : 019, Training: Loss - 0.4948, Accuracy - 76.9424%,
# 		Validation : Loss - 107.9591, Accuracy - 36.3636%, Recall - 1.0000, Time: 19.9783s
# Epoch: 21/50
# Epoch : 020, Training: Loss - 0.4558, Accuracy - 80.2005%,
# 		Validation : Loss - 28.2130, Accuracy - 36.3636%, Recall - 1.0000, Time: 19.6804s
# Epoch: 22/50
# Epoch : 021, Training: Loss - 0.4558, Accuracy - 78.9474%,
# 		Validation : Loss - 83.4018, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.7032s
# Epoch: 23/50
# Epoch : 022, Training: Loss - 0.4055, Accuracy - 81.9549%,
# 		Validation : Loss - 54.0435, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.7338s
# Epoch: 24/50
# Epoch : 023, Training: Loss - 0.4687, Accuracy - 76.6917%,
# 		Validation : Loss - 75.7771, Accuracy - 36.3636%, Recall - 1.0000, Time: 19.9082s
# Epoch: 25/50
# Epoch : 024, Training: Loss - 0.4740, Accuracy - 77.6942%,
# 		Validation : Loss - 80.7945, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.6438s
# Epoch: 26/50
# Epoch : 025, Training: Loss - 0.4626, Accuracy - 80.9524%,
# 		Validation : Loss - 103.9304, Accuracy - 36.3636%, Recall - 1.0000, Time: 19.8325s
# Epoch: 27/50
# Epoch : 026, Training: Loss - 0.4398, Accuracy - 79.6992%,
# 		Validation : Loss - 5.3458, Accuracy - 36.3636%, Recall - 1.0000, Time: 20.2753s
# Epoch: 28/50
# Epoch : 027, Training: Loss - 0.3888, Accuracy - 82.7068%,
# 		Validation : Loss - 0.9594, Accuracy - 60.0000%, Recall - 0.8000, Time: 19.7747s
# Epoch: 29/50
# Epoch : 028, Training: Loss - 0.3981, Accuracy - 83.4586%,
# 		Validation : Loss - 56.8708, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.8043s
# Epoch: 30/50
# Epoch : 029, Training: Loss - 0.4071, Accuracy - 84.7118%,
# 		Validation : Loss - 183.7302, Accuracy - 36.3636%, Recall - 1.0000, Time: 19.5247s
# Epoch: 31/50
# Epoch : 030, Training: Loss - 0.4577, Accuracy - 78.6967%,
# 		Validation : Loss - 18.8499, Accuracy - 63.6364%, Recall - 0.0000, Time: 20.2917s
# Epoch: 32/50
# Epoch : 031, Training: Loss - 0.4294, Accuracy - 80.7018%,
# 		Validation : Loss - 170.5950, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.8803s
# Epoch: 33/50
# Epoch : 032, Training: Loss - 0.3917, Accuracy - 83.2080%,
# 		Validation : Loss - 23.3060, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.8128s
# Epoch: 34/50
# Epoch : 033, Training: Loss - 0.4010, Accuracy - 81.7043%,
# 		Validation : Loss - 111.2221, Accuracy - 36.3636%, Recall - 1.0000, Time: 19.8656s
# Epoch: 35/50
# Epoch : 034, Training: Loss - 0.3910, Accuracy - 82.7068%,
# 		Validation : Loss - 88.9425, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.8030s
# Epoch: 36/50
# Epoch : 035, Training: Loss - 0.4743, Accuracy - 75.6892%,
# 		Validation : Loss - 62.3210, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.7497s
# Epoch: 37/50
# Epoch : 036, Training: Loss - 0.4140, Accuracy - 82.7068%,
# 		Validation : Loss - 20.3815, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.5174s
# Epoch: 38/50
# Epoch : 037, Training: Loss - 0.3911, Accuracy - 83.9599%,
# 		Validation : Loss - 70.9219, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.9084s
# Epoch: 39/50
# Epoch : 038, Training: Loss - 0.3658, Accuracy - 82.7068%,
# 		Validation : Loss - 64.4755, Accuracy - 36.3636%, Recall - 1.0000, Time: 20.0742s
# Epoch: 40/50
# Epoch : 039, Training: Loss - 0.3938, Accuracy - 83.9599%,
# 		Validation : Loss - 52.4065, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.7421s
# Epoch: 41/50
# Epoch : 040, Training: Loss - 0.3530, Accuracy - 84.4612%,
# 		Validation : Loss - 25.2636, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.8978s
# Epoch: 42/50
# Epoch : 041, Training: Loss - 0.3845, Accuracy - 84.9624%,
# 		Validation : Loss - 45.1860, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.7052s
# Epoch: 43/50
# Epoch : 042, Training: Loss - 0.3604, Accuracy - 84.2105%,
# 		Validation : Loss - 33.4473, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.7507s
# Epoch: 44/50
# Epoch : 043, Training: Loss - 0.3154, Accuracy - 87.9699%,
# 		Validation : Loss - 10.2597, Accuracy - 63.6364%, Recall - 0.0000, Time: 20.1670s
# Epoch: 45/50
# Epoch : 044, Training: Loss - 0.2781, Accuracy - 87.9699%,
# 		Validation : Loss - 19.5034, Accuracy - 36.3636%, Recall - 1.0000, Time: 20.0804s
# Epoch: 46/50
# Epoch : 045, Training: Loss - 0.3099, Accuracy - 86.7168%,
# 		Validation : Loss - 59.4559, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.9311s
# Epoch: 47/50
# Epoch : 046, Training: Loss - 0.2798, Accuracy - 88.9724%,
# 		Validation : Loss - 145.8752, Accuracy - 36.3636%, Recall - 1.0000, Time: 19.7855s
# Epoch: 48/50
# Epoch : 047, Training: Loss - 0.3353, Accuracy - 86.4662%,
# 		Validation : Loss - 48.8112, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.7145s
# Epoch: 49/50
# Epoch : 048, Training: Loss - 0.3355, Accuracy - 83.2080%,
# 		Validation : Loss - 70.6693, Accuracy - 63.6364%, Recall - 0.0000, Time: 19.6765s
# Epoch: 50/50
# Epoch : 049, Training: Loss - 0.3542, Accuracy - 84.9624%,
# 		Validation : Loss - 132.1474, Accuracy - 36.3636%, Recall - 1.0000, Time: 19.9011s

# %%
#lr=0.00015 (0.001 já não treina)
history = np.array(history)
plt.plot(history[:,0:2])
plt.legend(['Train Loss', 'Validation Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.show()

# %%
#lr=0.00015
plt.plot(history[:,2:4])
plt.legend(['Train Accuracy', 'Validation Accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim(0,1)
plt.show()

# %%
#lr=0.0001
history = np.array(history)
plt.plot(history[:,0:2])
plt.legend(['Train Loss', 'Validation Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim(0.7,0.8)
plt.show()

# %%
#lr=0.0001
plt.plot(history[:,2:4])
plt.legend(['Train Accuracy', 'Validation Accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim(0,1)
plt.show()

# %% [markdown]
# resnet 18 e 34 com fine tunning. fiz vários testes

# %%
resnet = models.resnet18(pretrained=True)
resnet = resnet.to(device)

# %%
print(resnet)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
for param in resnet.parameters():
    param.requires_grad = False

for idx in [0, 1]:
    for param in resnet.layer4[idx].parameters():
        param.requires_grad = True
for param in resnet.layer3[-1].parameters():
        param.requires_grad = True
resnet.fc = nn.Linear(resnet.fc.in_features, 2)
for param in resnet.fc.parameters():
    param.requires_grad = True

# %%
params_to_be_optim = [p for p in resnet.parameters() if p.requires_grad]

# %%
loss_func = nn.CrossEntropyLoss()
optimizer = optim.Adam(params_to_be_optim, lr=1e-4, weight_decay=1e-4)

# %%
batch_size = 30

# %%
num_epochs = 50
trained_model, history, best_epoch = train_and_validate(resnet, loss_func, optimizer, num_epochs)
torch.save(history, dataset+'_resnet34_history.pt')
# Out:
# Epoch: 1/50
# Epoch : 000, Training: Loss - 0.6278, Accuracy - 67.6692%,
# 		Validation : Loss - 0.6808, Accuracy - 56.3636%, Recall - 0.1500, Time: 36.9352s
# Epoch: 2/50
# Epoch : 001, Training: Loss - 0.5092, Accuracy - 75.4386%,
# 		Validation : Loss - 0.6117, Accuracy - 61.8182%, Recall - 0.2000, Time: 37.2786s
# Epoch: 3/50
# Epoch : 002, Training: Loss - 0.4298, Accuracy - 80.7018%,
# 		Validation : Loss - 0.6149, Accuracy - 67.2727%, Recall - 0.5000, Time: 36.5088s
# Epoch: 4/50
# Epoch : 003, Training: Loss - 0.3288, Accuracy - 85.2130%,
# 		Validation : Loss - 0.7923, Accuracy - 69.0909%, Recall - 0.7500, Time: 35.5951s
# Epoch: 5/50
# Epoch : 004, Training: Loss - 0.2928, Accuracy - 88.2206%,
# 		Validation : Loss - 0.8261, Accuracy - 69.0909%, Recall - 0.6500, Time: 35.4456s
# Epoch: 6/50
# Epoch : 005, Training: Loss - 0.2797, Accuracy - 87.9699%,
# 		Validation : Loss - 0.9872, Accuracy - 63.6364%, Recall - 0.8500, Time: 36.5116s
# Epoch: 7/50
# Epoch : 006, Training: Loss - 0.2452, Accuracy - 90.7268%,
# 		Validation : Loss - 0.8502, Accuracy - 69.0909%, Recall - 0.6500, Time: 38.0027s
# Epoch: 8/50
# Epoch : 007, Training: Loss - 0.2010, Accuracy - 91.4787%,
# 		Validation : Loss - 0.8135, Accuracy - 69.0909%, Recall - 0.4000, Time: 34.8274s
# Epoch: 9/50
# Epoch : 008, Training: Loss - 0.2136, Accuracy - 91.7293%,
# 		Validation : Loss - 0.9659, Accuracy - 56.3636%, Recall - 0.5000, Time: 34.8358s
# Epoch: 10/50
# Epoch : 009, Training: Loss - 0.1740, Accuracy - 93.9850%,
# 		Validation : Loss - 0.9817, Accuracy - 69.0909%, Recall - 0.7000, Time: 33.7711s
# Epoch: 11/50
# Epoch : 010, Training: Loss - 0.1680, Accuracy - 93.4837%,
# 		Validation : Loss - 1.0214, Accuracy - 70.9091%, Recall - 0.5000, Time: 34.2014s
# Epoch: 12/50
# Epoch : 011, Training: Loss - 0.0667, Accuracy - 97.2431%,
# 		Validation : Loss - 0.9714, Accuracy - 65.4545%, Recall - 0.6500, Time: 34.5888s
# Epoch: 13/50
# Epoch : 012, Training: Loss - 0.0853, Accuracy - 97.7444%,
# 		Validation : Loss - 1.0044, Accuracy - 78.1818%, Recall - 0.6000, Time: 34.8284s
# Epoch: 14/50
# Epoch : 013, Training: Loss - 0.1338, Accuracy - 95.2381%,
# 		Validation : Loss - 1.1107, Accuracy - 69.0909%, Recall - 0.6000, Time: 35.5407s
# Epoch: 15/50
# Epoch : 014, Training: Loss - 0.1074, Accuracy - 97.2431%,
# 		Validation : Loss - 1.2200, Accuracy - 70.9091%, Recall - 0.5500, Time: 29.7235s
# Epoch: 16/50
# Epoch : 015, Training: Loss - 0.1239, Accuracy - 95.4887%,
# 		Validation : Loss - 1.1206, Accuracy - 63.6364%, Recall - 0.8000, Time: 29.4204s
# Epoch: 17/50
# Epoch : 016, Training: Loss - 0.1130, Accuracy - 96.2406%,
# 		Validation : Loss - 1.0715, Accuracy - 70.9091%, Recall - 0.7500, Time: 29.3300s
# Epoch: 18/50
# Epoch : 017, Training: Loss - 0.1128, Accuracy - 95.4887%,
# 		Validation : Loss - 0.9083, Accuracy - 70.9091%, Recall - 0.5000, Time: 29.6854s
# Epoch: 19/50
# Epoch : 018, Training: Loss - 0.0880, Accuracy - 96.9925%,
# 		Validation : Loss - 0.9074, Accuracy - 70.9091%, Recall - 0.8000, Time: 29.3049s
# Epoch: 20/50
# Epoch : 019, Training: Loss - 0.0550, Accuracy - 98.2456%,
# 		Validation : Loss - 1.2173, Accuracy - 69.0909%, Recall - 0.7000, Time: 29.4427s
# Epoch: 21/50
# Epoch : 020, Training: Loss - 0.1009, Accuracy - 94.9875%,
# 		Validation : Loss - 0.9206, Accuracy - 74.5455%, Recall - 0.7000, Time: 29.3292s
# Epoch: 22/50
# Epoch : 021, Training: Loss - 0.1287, Accuracy - 94.7368%,
# 		Validation : Loss - 0.9411, Accuracy - 76.3636%, Recall - 0.7500, Time: 29.4054s
# Epoch: 23/50
# Epoch : 022, Training: Loss - 0.0543, Accuracy - 97.9950%,
# 		Validation : Loss - 1.2462, Accuracy - 69.0909%, Recall - 0.5000, Time: 29.5100s
# Epoch: 24/50
# Epoch : 023, Training: Loss - 0.0598, Accuracy - 97.4937%,
# 		Validation : Loss - 1.2083, Accuracy - 67.2727%, Recall - 0.7500, Time: 29.2754s
# Epoch: 25/50
# Epoch : 024, Training: Loss - 0.0848, Accuracy - 96.7419%,
# 		Validation : Loss - 1.0175, Accuracy - 65.4545%, Recall - 0.7000, Time: 29.3964s
# Epoch: 26/50
# Epoch : 025, Training: Loss - 0.0646, Accuracy - 97.9950%,
# 		Validation : Loss - 1.2061, Accuracy - 70.9091%, Recall - 0.6000, Time: 29.7208s
# Epoch: 27/50
# Epoch : 026, Training: Loss - 0.0888, Accuracy - 95.4887%,
# 		Validation : Loss - 1.3021, Accuracy - 69.0909%, Recall - 0.4500, Time: 29.6050s
# Epoch: 28/50
# Epoch : 027, Training: Loss - 0.0609, Accuracy - 96.9925%,
# 		Validation : Loss - 1.2190, Accuracy - 70.9091%, Recall - 0.5000, Time: 29.6337s
# Epoch: 29/50
# Epoch : 028, Training: Loss - 0.0873, Accuracy - 96.2406%,
# 		Validation : Loss - 1.3638, Accuracy - 72.7273%, Recall - 0.4500, Time: 29.3943s
# Epoch: 30/50
# Epoch : 029, Training: Loss - 0.0767, Accuracy - 97.2431%,
# 		Validation : Loss - 0.9171, Accuracy - 74.5455%, Recall - 0.5000, Time: 29.5018s
# Epoch: 31/50
# Epoch : 030, Training: Loss - 0.0537, Accuracy - 97.7444%,
# 		Validation : Loss - 1.0974, Accuracy - 78.1818%, Recall - 0.7000, Time: 34.1317s
# Epoch: 32/50
# Epoch : 031, Training: Loss - 0.0807, Accuracy - 96.7419%,
# 		Validation : Loss - 0.9988, Accuracy - 76.3636%, Recall - 0.5500, Time: 30.0204s
# Epoch: 33/50
# Epoch : 032, Training: Loss - 0.0493, Accuracy - 97.9950%,
# 		Validation : Loss - 1.1704, Accuracy - 70.9091%, Recall - 0.6500, Time: 35.6665s
# Epoch: 34/50
# Epoch : 033, Training: Loss - 0.0454, Accuracy - 98.7469%,
# 		Validation : Loss - 0.9655, Accuracy - 74.5455%, Recall - 0.8000, Time: 32.1920s
# Epoch: 35/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[145], line 2
#       1 num_epochs = 50
# ----> 2 trained_model, history, best_epoch = train_and_validate(resnet, loss_func, optimizer, num_epochs)
#       3 torch.save(history, dataset+'_resnet34_history.pt')
#
# Cell In[26], line 36, in train_and_validate(model, loss_criterion, optimizer, epochs, dataset, train_data_loader, val_data_loader, train_data_size, val_data_size, device)
#      33 optimizer.zero_grad()
#      35 # Forward pass - compute outputs on input data using the model
# ---> 36 outputs = model(inputs)
#      38 # Compute loss
#      39 loss = loss_criterion(outputs, labels)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torchvision/models/resnet.py:285, in ResNet.forward(self, x)
#     284 def forward(self, x: Tensor) -> Tensor:
# --> 285     return self._forward_impl(x)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torchvision/models/resnet.py:276, in ResNet._forward_impl(self, x)
#     274 x = self.layer2(x)
#     275 x = self.layer3(x)
# --> 276 x = self.layer4(x)
#     278 x = self.avgpool(x)
#     279 x = torch.flatten(x, 1)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/nn/modules/container.py:240, in Sequential.forward(self, input)
#     238 def forward(self, input):
#     239     for module in self:
# --> 240         input = module(input)
#     241     return input
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torchvision/models/resnet.py:96, in BasicBlock.forward(self, x)
#      93 out = self.bn1(out)
#      94 out = self.relu(out)
# ---> 96 out = self.conv2(out)
#      97 out = self.bn2(out)
#      99 if self.downsample is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:

# %%
history = np.array(history)
plt.plot(history[:,0:2])
plt.legend(['Train Loss', 'Validation Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(history[:,2:4])
plt.legend(['Train Accuracy', 'Validation Accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# Vi sinais de overfitting consistentemente durante os testes. Então, decidi experimentar uma arquitetura mais simples.

# %%
model = models.squeezenet1_0(pretrained=True)

# %%
print(model)
# Out:
# SqueezeNet(
#   (features): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(7, 7), stride=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (3): Fire(
#       (squeeze): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (4): Fire(
#       (squeeze): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (5): Fire(
#       (squeeze): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (6): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (7): Fire(
#       (squeeze): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (8): Fire(
#       (squeeze): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (9): Fire(
#       (squeeze): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (10): Fire(
#       (squeeze): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (11): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (12): Fire(
#       (squeeze): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Conv2d(512, 1000, kernel_size=(1, 1), stride=(1, 1))
#     (2): ReLU(inplace=True)
#     (3): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
# )

# %%
model.classifier[1] = nn.Conv2d(512, 2, kernel_size=(1,1), stride=(1,1))
model.num_classes = 2

# %%
for param in model.features.parameters():
    param.requires_grad = False 

for param in model.classifier.parameters():
    param.requires_grad = True 

for param in model.features[10:].parameters():  
    param.requires_grad = True

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=1e-3, weight_decay=1e-4)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# %%
num_epochs = 50
trained_model, history, best_epoch = train_and_validate(model, loss_func, optimizer, num_epochs)
# Out:
# Epoch: 1/50
# Epoch : 000, Training: Loss - 0.6931, Accuracy - 63.6591%,
# 		Validation : Loss - 0.6931, Accuracy - 63.6364%, Recall - 0.0000, Time: 25.4723s
# Epoch: 2/50
# Epoch : 001, Training: Loss - 0.6931, Accuracy - 63.9098%,
# 		Validation : Loss - 0.6931, Accuracy - 63.6364%, Recall - 0.0000, Time: 25.3138s
# Epoch: 3/50
# Epoch : 002, Training: Loss - 0.6931, Accuracy - 63.9098%,
# 		Validation : Loss - 0.6931, Accuracy - 63.6364%, Recall - 0.0000, Time: 25.2571s
# Epoch: 4/50
# Epoch : 003, Training: Loss - 0.6931, Accuracy - 63.9098%,
# 		Validation : Loss - 0.6931, Accuracy - 63.6364%, Recall - 0.0000, Time: 25.3121s
# Epoch: 5/50
# Epoch : 004, Training: Loss - 0.6931, Accuracy - 63.9098%,
# 		Validation : Loss - 0.6931, Accuracy - 63.6364%, Recall - 0.0000, Time: 25.0908s
# Epoch: 6/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[175], line 2
#       1 num_epochs = 50
# ----> 2 trained_model, history, best_epoch = train_and_validate(model, loss_func, optimizer, num_epochs)
#
# Cell In[26], line 27, in train_and_validate(model, loss_criterion, optimizer, epochs, dataset, train_data_loader, val_data_loader, train_data_size, val_data_size, device)
#      24 valid_false_negatives = 0.0
#      26 #for each batch
# ---> 27 for i, (inputs, labels) in enumerate(train_data_loader):
#      29     inputs = inputs.to(device)
#      30     labels = labels.to(device)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/utils/data/dataloader.py:733, in _BaseDataLoaderIter.__next__(self)
#     730 if self._sampler_iter is None:
#     731     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732     self._reset()  # type: ignore[call-arg]
# --> 733 data = self._next_data()
#     734 self._num_yielded += 1
#     735 if (
#     736     self._dataset_kind == _DatasetKind.Iterable
#     737     and self._IterableDataset_len_called is not None
#     738     and self._num_yielded > self._IterableDataset_len_called
#     739 ):
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/utils/data/dataloader.py:789, in _SingleProcessDataLoaderIter._next_data(self)
#     787 def _next_data(self):
#     788     index = self._next_index()  # may raise StopIteration
# --> 789     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     790     if self._pin_memory:
#     791         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torchvision/datasets/folder.py:245, in DatasetFolder.__getitem__(self, index)
#     237 """
#     238 Args:
#     239     index (int): Index
#    (...)
#     242     tuple: (sample, target) where target is class_index of the target class.
#     243 """
#     244 path, target = self.samples[index]
# --> 245 sample = self.loader(path)
#     246 if self.transform is not None:
#     247     sample = self.transform(sample)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torchvision/datasets/folder.py:284, in default_loader(path)
#     282     return accimage_loader(path)
#     283 else:
# --> 284     return pil_loader(path)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torchvision/datasets/folder.py:264, in pil_loader(path)
#     262 with open(path, "rb") as f:
#     263     img = Image.open(f)
# --> 264     return img.convert("RGB")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/PIL/Image.py:1143, in Image.convert(self, mode, matrix, dither, palette, colors)
#    1140     dither = Dither.FLOYDSTEINBERG
#    1142 try:
# -> 1143     im = self.im.convert(mode, dither)
#    1144 except ValueError:
#    1145     try:
#    1146         # normalize source image and try again
#
# KeyboardInterrupt:

# %% [markdown]
# Com essa arquitetura, vi sinais consistentes de underfitting, o que me indicou para um caminho do meio. Foi o que fiz, partindo para a mobilenetv2

# %%
mobilenet = models.mobilenet_v2(pretrained=True)
mobilenet.classifier[1] = nn.Linear(mobilenet.last_channel, 2)

# %%
print(mobilenet)
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=2, bias=True)
#   )
# )

# %%
for param in mobilenet.features.parameters():
    param.requires_grad = False  

for param in mobilenet.classifier.parameters():
    param.requires_grad = True 

for param in mobilenet.features[-5:].parameters(): 
    param.requires_grad = True

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam([p for p in mobilenet.parameters() if p.requires_grad], lr=7e-6)

# %%
num_epochs = 35
trained_model, history, best_epoch = train_and_validate(mobilenet, loss_func, optimizer, num_epochs)
# Out:
# Epoch: 1/35
# Epoch : 000, Training: Loss - 0.0215, Accuracy - 99.7494%,
# 		Validation : Loss - 1.1555, Accuracy - 74.5455%, Recall - 0.5500, Time: 105.1639s
# Epoch: 2/35

# %%
history = np.array(history)
plt.plot(history[:,0:2])
plt.legend(['Train Loss', 'Validation Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(history[:,2:4])
plt.legend(['Train Accuracy', 'Validation Accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %%
mobilenet = models.mobilenet_v2(pretrained=True)
mobilenet.classifier[1] = nn.Linear(mobilenet.last_channel, 2)

# %%
print(mobilenet)
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=2, bias=True)
#   )
# )

# %%
for param in mobilenet.features.parameters():
    param.requires_grad = False  

for param in mobilenet.classifier.parameters():
    param.requires_grad = True 

for param in mobilenet.features[-4:].parameters(): 
    param.requires_grad = True

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam([p for p in mobilenet.parameters() if p.requires_grad], lr=2e-4)

# %%
num_epochs = 60
trained_model, history, best_epoch = train_and_validate(mobilenet, loss_func, optimizer, num_epochs)
# Out:
# Epoch: 1/60
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[253], line 2
#       1 num_epochs = 60
# ----> 2 trained_model, history, best_epoch = train_and_validate(mobilenet, loss_func, optimizer, num_epochs)
#
# Cell In[26], line 27, in train_and_validate(model, loss_criterion, optimizer, epochs, dataset, train_data_loader, val_data_loader, train_data_size, val_data_size, device)
#      24 valid_false_negatives = 0.0
#      26 #for each batch
# ---> 27 for i, (inputs, labels) in enumerate(train_data_loader):
#      29     inputs = inputs.to(device)
#      30     labels = labels.to(device)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/utils/data/dataloader.py:733, in _BaseDataLoaderIter.__next__(self)
#     730 if self._sampler_iter is None:
#     731     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732     self._reset()  # type: ignore[call-arg]
# --> 733 data = self._next_data()
#     734 self._num_yielded += 1
#     735 if (
#     736     self._dataset_kind == _DatasetKind.Iterable
#     737     and self._IterableDataset_len_called is not None
#     738     and self._num_yielded > self._IterableDataset_len_called
#     739 ):
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/utils/data/dataloader.py:789, in _SingleProcessDataLoaderIter._next_data(self)
#     787 def _next_data(self):
#     788     index = self._next_index()  # may raise StopIteration
# --> 789     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     790     if self._pin_memory:
#     791         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torchvision/datasets/folder.py:247, in DatasetFolder.__getitem__(self, index)
#     245 sample = self.loader(path)
#     246 if self.transform is not None:
# --> 247     sample = self.transform(sample)
#     248 if self.target_transform is not None:
#     249     target = self.target_transform(target)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torchvision/transforms/transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torchvision/transforms/transforms.py:354, in Resize.forward(self, img)
#     346 def forward(self, img):
#     347     """
#     348     Args:
#     349         img (PIL Image or Tensor): Image to be scaled.
#    (...)
#     352         PIL Image or Tensor: Rescaled image.
#     353     """
# --> 354     return F.resize(img, self.size, self.interpolation, self.max_size, self.antialias)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torchvision/transforms/functional.py:477, in resize(img, size, interpolation, max_size, antialias)
#     475         warnings.warn("Anti-alias option is always applied for PIL Image input. Argument antialias is ignored.")
#     476     pil_interpolation = pil_modes_mapping[interpolation]
# --> 477     return F_pil.resize(img, size=output_size, interpolation=pil_interpolation)
#     479 return F_t.resize(img, size=output_size, interpolation=interpolation.value, antialias=antialias)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/torchvision/transforms/_functional_pil.py:250, in resize(img, size, interpolation)
#     247 if not (isinstance(size, list) and len(size) == 2):
#     248     raise TypeError(f"Got inappropriate size arg: {size}")
# --> 250 return img.resize(tuple(size[::-1]), interpolation)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/PIL/Image.py:2356, in Image.resize(self, size, resample, box, reducing_gap)
#    2344         self = (
#    2345             self.reduce(factor, box=reduce_box)
#    2346             if callable(self.reduce)
#    2347             else Image.reduce(self, factor, box=reduce_box)
#    2348         )
#    2349         box = (
#    2350             (box[0] - reduce_box[0]) / factor_x,
#    2351             (box[1] - reduce_box[1]) / factor_y,
#    2352             (box[2] - reduce_box[0]) / factor_x,
#    2353             (box[3] - reduce_box[1]) / factor_y,
#    2354         )
# -> 2356 return self._new(self.im.resize(size, resample, box))
#
# KeyboardInterrupt:

# %%
history = np.array(history)
plt.plot(history[:,0:2])
plt.legend(['Train Loss', 'Validation Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(history[:,2:4])
plt.legend(['Train Accuracy', 'Validation Accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# Aqui, mesma rede de cima, com as mesmas configurações, mas retreinando, do zero, 5 convoluções.

# %%
mobilenet = models.mobilenet_v2(pretrained=True)
mobilenet.classifier[1] = nn.Linear(mobilenet.last_channel, 2)

# %%
for param in mobilenet.features.parameters():
    param.requires_grad = False  

for param in mobilenet.classifier.parameters():
    param.requires_grad = True 

for param in mobilenet.features[-2:].parameters(): 
    param.requires_grad = True

# %%
loss_func = nn.CrossEntropyLoss()
optimizer = optim.Adam([p for p in mobilenet.parameters() if p.requires_grad], lr=0.0009)

# %%
batch_size = 48

# %%
num_epochs = 60
trained_model, history, best_epoch = train_and_validate(mobilenet, loss_func, optimizer, num_epochs)
# Out:
# Epoch: 1/60
# Epoch : 000, Training: Loss - 0.6757, Accuracy - 64.1604%,
# 		Validation : Loss - 0.6117, Accuracy - 65.4545%, Recall - 0.7500, Time: 84.9373s
# Epoch: 2/60
# Epoch : 001, Training: Loss - 0.6641, Accuracy - 60.1504%,
# 		Validation : Loss - 0.5733, Accuracy - 72.7273%, Recall - 0.6000, Time: 90.5717s
# Epoch: 3/60
# Epoch : 002, Training: Loss - 0.6161, Accuracy - 64.1604%,
# 		Validation : Loss - 0.5932, Accuracy - 63.6364%, Recall - 0.7000, Time: 89.2369s
# Epoch: 4/60
# Epoch : 003, Training: Loss - 0.6369, Accuracy - 65.9148%,
# 		Validation : Loss - 0.5705, Accuracy - 69.0909%, Recall - 0.4500, Time: 90.7095s
# Epoch: 5/60
# Epoch : 004, Training: Loss - 0.6333, Accuracy - 66.9173%,
# 		Validation : Loss - 0.5418, Accuracy - 70.9091%, Recall - 0.4500, Time: 89.3214s
# Epoch: 6/60
# Epoch : 005, Training: Loss - 0.6555, Accuracy - 64.1604%,
# 		Validation : Loss - 0.7251, Accuracy - 65.4545%, Recall - 0.0500, Time: 89.1337s
# Epoch: 7/60
# Epoch : 006, Training: Loss - 0.6257, Accuracy - 67.6692%,
# 		Validation : Loss - 0.7001, Accuracy - 63.6364%, Recall - 1.0000, Time: 90.1926s
# Epoch: 8/60
# Epoch : 007, Training: Loss - 0.6560, Accuracy - 66.4160%,
# 		Validation : Loss - 0.6674, Accuracy - 61.8182%, Recall - 0.9000, Time: 89.3031s
# Epoch: 9/60
# Epoch : 008, Training: Loss - 0.6461, Accuracy - 64.9123%,
# 		Validation : Loss - 0.6296, Accuracy - 61.8182%, Recall - 0.7500, Time: 93.2316s
# Epoch: 10/60
# Epoch : 009, Training: Loss - 0.6235, Accuracy - 66.1654%,
# 		Validation : Loss - 0.6240, Accuracy - 67.2727%, Recall - 0.3000, Time: 93.2765s
# Epoch: 11/60
# Epoch : 010, Training: Loss - 0.6273, Accuracy - 66.4160%,
# 		Validation : Loss - 0.5874, Accuracy - 67.2727%, Recall - 0.3000, Time: 88.1857s
# Epoch: 12/60
# Epoch : 011, Training: Loss - 0.6443, Accuracy - 64.9123%,
# 		Validation : Loss - 0.5768, Accuracy - 67.2727%, Recall - 0.4500, Time: 88.7778s
# Epoch: 13/60
# Epoch : 012, Training: Loss - 0.6199, Accuracy - 65.9148%,
# 		Validation : Loss - 0.5743, Accuracy - 67.2727%, Recall - 0.5500, Time: 88.7408s
# Epoch: 14/60
# Epoch : 013, Training: Loss - 0.6483, Accuracy - 64.9123%,
# 		Validation : Loss - 0.6211, Accuracy - 61.8182%, Recall - 0.7500, Time: 90.4278s
# Epoch: 15/60
# Epoch : 014, Training: Loss - 0.6199, Accuracy - 66.9173%,
# 		Validation : Loss - 0.5898, Accuracy - 60.0000%, Recall - 0.6000, Time: 89.8951s
# Epoch: 16/60
# Epoch : 015, Training: Loss - 0.6218, Accuracy - 66.6667%,
# 		Validation : Loss - 0.5827, Accuracy - 70.9091%, Recall - 0.4500, Time: 88.6530s
# Epoch: 17/60
# Epoch : 016, Training: Loss - 0.6460, Accuracy - 64.1604%,
# 		Validation : Loss - 0.6826, Accuracy - 52.7273%, Recall - 0.8000, Time: 89.8984s
# Epoch: 18/60
# Epoch : 017, Training: Loss - 0.6164, Accuracy - 68.4211%,
# 		Validation : Loss - 0.5774, Accuracy - 67.2727%, Recall - 0.4500, Time: 89.1102s
# Epoch: 19/60
# Epoch : 018, Training: Loss - 0.6159, Accuracy - 68.6717%,
# 		Validation : Loss - 0.6092, Accuracy - 63.6364%, Recall - 0.7500, Time: 77.1435s
# Epoch: 20/60
# Epoch : 019, Training: Loss - 0.6249, Accuracy - 67.1679%,
# 		Validation : Loss - 0.6025, Accuracy - 67.2727%, Recall - 0.7000, Time: 69.2473s
# Epoch: 21/60
# Epoch : 020, Training: Loss - 0.6092, Accuracy - 67.9198%,
# 		Validation : Loss - 0.5705, Accuracy - 67.2727%, Recall - 0.6500, Time: 68.6049s
# Epoch: 22/60
# Epoch : 021, Training: Loss - 0.6122, Accuracy - 67.4185%,
# 		Validation : Loss - 0.6285, Accuracy - 67.2727%, Recall - 0.8500, Time: 68.8924s
# Epoch: 23/60
# Epoch : 022, Training: Loss - 0.6356, Accuracy - 64.6617%,
# 		Validation : Loss - 0.5671, Accuracy - 72.7273%, Recall - 0.5000, Time: 67.7914s
# Epoch: 24/60
# Epoch : 023, Training: Loss - 0.6122, Accuracy - 66.4160%,
# 		Validation : Loss - 0.5961, Accuracy - 65.4545%, Recall - 0.6000, Time: 67.7017s
# Epoch: 25/60
# Epoch : 024, Training: Loss - 0.6287, Accuracy - 65.4135%,
# 		Validation : Loss - 0.6132, Accuracy - 70.9091%, Recall - 0.4000, Time: 68.3866s
# Epoch: 26/60
# Epoch : 025, Training: Loss - 0.6121, Accuracy - 66.1654%,
# 		Validation : Loss - 0.5879, Accuracy - 67.2727%, Recall - 0.4500, Time: 68.3460s
# Epoch: 27/60
# Epoch : 026, Training: Loss - 0.6122, Accuracy - 66.9173%,
# 		Validation : Loss - 0.5983, Accuracy - 67.2727%, Recall - 0.5000, Time: 69.0597s
# Epoch: 28/60
# Epoch : 027, Training: Loss - 0.6135, Accuracy - 68.1704%,
# 		Validation : Loss - 0.6007, Accuracy - 67.2727%, Recall - 0.3500, Time: 68.4183s
# Epoch: 29/60
# Epoch : 028, Training: Loss - 0.6054, Accuracy - 68.1704%,
# 		Validation : Loss - 0.5949, Accuracy - 67.2727%, Recall - 0.5000, Time: 68.5255s
# Epoch: 30/60
# Epoch : 029, Training: Loss - 0.6127, Accuracy - 64.1604%,
# 		Validation : Loss - 0.5892, Accuracy - 70.9091%, Recall - 0.6500, Time: 68.1805s
# Epoch: 31/60
# Epoch : 030, Training: Loss - 0.6254, Accuracy - 63.9098%,
# 		Validation : Loss - 0.6018, Accuracy - 72.7273%, Recall - 0.4500, Time: 68.9915s
# Epoch: 32/60
# Epoch : 031, Training: Loss - 0.6146, Accuracy - 67.6692%,
# 		Validation : Loss - 0.6683, Accuracy - 67.2727%, Recall - 0.5000, Time: 72.0180s
# Epoch: 33/60
# Epoch : 032, Training: Loss - 0.6015, Accuracy - 66.6667%,
# 		Validation : Loss - 0.7504, Accuracy - 56.3636%, Recall - 0.8500, Time: 71.2029s
# Epoch: 34/60
# Epoch : 033, Training: Loss - 0.6436, Accuracy - 63.9098%,
# 		Validation : Loss - 0.6966, Accuracy - 61.8182%, Recall - 0.8000, Time: 68.9153s
# Epoch: 35/60
# Epoch : 034, Training: Loss - 0.6063, Accuracy - 67.6692%,
# 		Validation : Loss - 0.7375, Accuracy - 56.3636%, Recall - 0.8500, Time: 68.2090s
# Epoch: 36/60
# Epoch : 035, Training: Loss - 0.6190, Accuracy - 65.4135%,
# 		Validation : Loss - 0.7212, Accuracy - 58.1818%, Recall - 0.8500, Time: 68.0896s
# Epoch: 37/60
# Epoch : 036, Training: Loss - 0.6184, Accuracy - 63.1579%,
# 		Validation : Loss - 0.5899, Accuracy - 67.2727%, Recall - 0.4500, Time: 68.2480s
# Epoch: 38/60
# Epoch : 037, Training: Loss - 0.5996, Accuracy - 68.9223%,
# 		Validation : Loss - 0.6043, Accuracy - 69.0909%, Recall - 0.4000, Time: 68.5305s
# Epoch: 39/60
# Epoch : 038, Training: Loss - 0.5908, Accuracy - 67.9198%,
# 		Validation : Loss - 0.7914, Accuracy - 58.1818%, Recall - 0.8500, Time: 67.8190s
# Epoch: 40/60
# Epoch : 039, Training: Loss - 0.6214, Accuracy - 66.4160%,
# 		Validation : Loss - 0.5524, Accuracy - 72.7273%, Recall - 0.6500, Time: 68.9222s
# Epoch: 41/60
# Epoch : 040, Training: Loss - 0.5769, Accuracy - 71.4286%,
# 		Validation : Loss - 0.6070, Accuracy - 69.0909%, Recall - 0.7000, Time: 68.4303s
# Epoch: 42/60
# Epoch : 041, Training: Loss - 0.5847, Accuracy - 68.4211%,
# 		Validation : Loss - 0.6302, Accuracy - 72.7273%, Recall - 0.8000, Time: 69.1907s
# Epoch: 43/60
# Epoch : 042, Training: Loss - 0.5894, Accuracy - 68.9223%,
# 		Validation : Loss - 0.7515, Accuracy - 70.9091%, Recall - 0.3500, Time: 68.4528s
# Epoch: 44/60
# Epoch : 043, Training: Loss - 0.6008, Accuracy - 69.9248%,
# 		Validation : Loss - 0.6708, Accuracy - 70.9091%, Recall - 0.8500, Time: 68.4363s
# Epoch: 45/60
# Epoch : 044, Training: Loss - 0.5842, Accuracy - 68.6717%,
# 		Validation : Loss - 0.7425, Accuracy - 65.4545%, Recall - 0.8500, Time: 69.0888s
# Epoch: 46/60
# Epoch : 045, Training: Loss - 0.6405, Accuracy - 66.4160%,
# 		Validation : Loss - 0.5879, Accuracy - 70.9091%, Recall - 0.7000, Time: 68.7865s
# Epoch: 47/60
# Epoch : 046, Training: Loss - 0.6112, Accuracy - 66.9173%,
# 		Validation : Loss - 0.6094, Accuracy - 70.9091%, Recall - 0.8000, Time: 62.0598s
# Epoch: 48/60
# Epoch : 047, Training: Loss - 0.6136, Accuracy - 65.9148%,
# 		Validation : Loss - 0.7079, Accuracy - 65.4545%, Recall - 0.2000, Time: 41.5806s
# Epoch: 49/60
# Epoch : 048, Training: Loss - 0.6200, Accuracy - 65.1629%,
# 		Validation : Loss - 0.6059, Accuracy - 72.7273%, Recall - 0.5500, Time: 41.1290s
# Epoch: 50/60
# Epoch : 049, Training: Loss - 0.5949, Accuracy - 69.6742%,
# 		Validation : Loss - 0.6167, Accuracy - 69.0909%, Recall - 0.7000, Time: 41.1593s
# Epoch: 51/60
# Epoch : 050, Training: Loss - 0.5941, Accuracy - 68.4211%,
# 		Validation : Loss - 0.6868, Accuracy - 60.0000%, Recall - 0.7500, Time: 41.1232s
# Epoch: 52/60
# Epoch : 051, Training: Loss - 0.5787, Accuracy - 70.4261%,
# 		Validation : Loss - 0.6263, Accuracy - 67.2727%, Recall - 0.6000, Time: 41.1507s
# Epoch: 53/60
# Epoch : 052, Training: Loss - 0.6043, Accuracy - 67.9198%,
# 		Validation : Loss - 0.6215, Accuracy - 60.0000%, Recall - 0.6000, Time: 41.1516s
# Epoch: 54/60
# Epoch : 053, Training: Loss - 0.5753, Accuracy - 68.4211%,
# 		Validation : Loss - 0.7439, Accuracy - 61.8182%, Recall - 0.8500, Time: 41.1494s
# Epoch: 55/60
# Epoch : 054, Training: Loss - 0.5824, Accuracy - 66.6667%,
# 		Validation : Loss - 0.6112, Accuracy - 74.5455%, Recall - 0.7500, Time: 41.0854s
# Epoch: 56/60
# Epoch : 055, Training: Loss - 0.5969, Accuracy - 67.6692%,
# 		Validation : Loss - 0.6121, Accuracy - 69.0909%, Recall - 0.7000, Time: 41.0665s
# Epoch: 57/60
# Epoch : 056, Training: Loss - 0.5866, Accuracy - 68.1704%,
# 		Validation : Loss - 0.6277, Accuracy - 70.9091%, Recall - 0.3500, Time: 41.1303s
# Epoch: 58/60
# Epoch : 057, Training: Loss - 0.5924, Accuracy - 67.1679%,
# 		Validation : Loss - 0.6913, Accuracy - 67.2727%, Recall - 0.3500, Time: 41.1474s
# Epoch: 59/60
# Epoch : 058, Training: Loss - 0.6303, Accuracy - 66.1654%,
# 		Validation : Loss - 0.8064, Accuracy - 56.3636%, Recall - 0.9000, Time: 41.0812s
# Epoch: 60/60
# Epoch : 059, Training: Loss - 0.6227, Accuracy - 66.6667%,
# 		Validation : Loss - 0.5841, Accuracy - 70.9091%, Recall - 0.5000, Time: 41.2591s

# %%
history = np.array(history)
plt.plot(history[:,0:2])
plt.legend(['Train Loss', 'Validation Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(history[:,2:4])
plt.legend(['Train Accuracy', 'Validation Accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()
